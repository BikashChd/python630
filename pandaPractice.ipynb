# %%
import pandas as pd 
df=pd.read_csv('pandacsv.csv')
df
# Out:
#    S.N       Name  Age        Address        Phone
# 0    1     Bikash   24        Surkhet   9848004644
# 1    2     Ramesh   27          Dullu   9802547801
# 2    3  Khagendra   25  Birendranager  98303003030
# 3    4     Malati   16           Dang   9812345678
# 4    5       Hari   34      Bhaktapur    871234567
# 5    6     Brinda   25        Koldata   9868091778

# %%
import pandas as pd
df=pd.read_csv('pandacsv.csv')
df.head(2)
# Out:
#    S.N    Name  Age  Address       Phone
# 0    1  Bikash   24  Surkhet  9848004644
# 1    2  Ramesh   27    Dullu  9802547801

# %%
df.tail(4)
# Out:
#    S.N       Name  Age        Address        Phone
# 2    3  Khagendra   25  Birendranager  98303003030
# 3    4     Malati   16           Dang   9812345678
# 4    5       Hari   34      Bhaktapur    871234567
# 5    6     Brinda   25        Koldata   9868091778

# %%
df=pd.read_csv('pandacsv.csv',index_col='SN')
df
# Out:
#          Name  Age        Address        Phone
# SN
# 1      Bikash   24        Surkhet   9848004644
# 2      Ramesh   27          Dullu   9802547801
# 3   Khagendra   25  Birendranager  98303003030
# 4      Malati   16           Dang   9812345678
# 5        Hari   34      Bhaktapur    871234567
# 6      Brinda   25        Koldata   9868091778

# %%
df=pd.read_csv('pandacsv.csv',index_col='SN',usecols=['SN','Name','Age'])
df
# Out:
#          Name  Age
# SN
# 1      Bikash   24
# 2      Ramesh   27
# 3   Khagendra   25
# 4      Malati   16
# 5        Hari   34
# 6      Brinda   25

# %%
import pandas as pd 
df=pd.read_csv('pandacsv.csv',index_col='SN')
df[(df['Address']=='Surkhet') & (df['Age']>20) ]
# Out:
#       Name  Age  Address       Phone
# SN
# 1   Bikash   24  Surkhet  9848004644

# %%
# dictionary data into csv file
import pandas as pd
d={
    'name':['Ram','Shyam','Hari','Gita','Arun'],
    'add':['Skt','Npj','India','China','Bhutan'],
    'phone':[9848,464,1234,2343,4567]
}
di=pd.DataFrame(d)
di.to_csv('dictPractice.csv')

# %%
# saving list data into csv file
import csv
data=[6,'Bikash','Surkhet',30]
f=open ('listData.csv','x')
a=csv.writer(f)
a.writerow(data)
# Out:
# 21
